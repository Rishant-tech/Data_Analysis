# %% [markdown]
# # pandas----> pannel data

# %%
d={"Name":['Rishant','Ankit','X'],"Age":[21,25,30],"City":["Delhi","Delhi","Y"]}

# %%
d
# Out:
# {'Name': ['Rishant', 'Ankit', 'X'],
#  'Age': [21, 25, 30],
#  'City': ['Delhi', 'Delhi', 'Y']}

# %%
import pandas as pd

# %%
df=pd.DataFrame(d)

# %%
df
# Out:
#       Name  Age   City
# 0  Rishant   21  Delhi
# 1    Ankit   25  Delhi
# 2        X   30      Y

# %%
df.to_csv("myfirstfile.csv")

# %%
df.to_excel("myexl.xlsx")

# %%
# importing data
# df=pd.read_csv(raw string'path/name/fileextension')
df=pd.read_csv(r'C:\Users\rajri\Downloads\CAR DETAILS FROM CAR DEKHO.csv')

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %%
# how to look or observe the data
# head
# tail
# sample

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
# ...

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.head(10)
# Out:
#                         name  year  selling_price  km_driven    fuel  \
# 0              Maruti 800 AC  2007          60000      70000  Petrol
# 1   Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2       Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3     Datsun RediGO T Option  2017         250000      46000  Petrol
# 4      Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
# 5       Maruti Alto LX BSIII  2007         140000     125000  Petrol
# 6  Hyundai Xcent 1.2 Kappa S  2016         550000      25000  Petrol
# 7   Tata Indigo Grand Petrol  2014         240000      60000  Petrol
# 8   Hyundai Creta 1.6 VTVT S  2015         850000      25000  Petrol
# 9   Maruti Celerio Green VXI  2017         365000      78000     CNG
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# ...

# %%
df.head(50)
# Out:
#                                               name  year  selling_price  \
# 0                                    Maruti 800 AC  2007          60000
# 1                         Maruti Wagon R LXI Minor  2007         135000
# 2                             Hyundai Verna 1.6 SX  2012         600000
# 3                           Datsun RediGO T Option  2017         250000
# 4                            Honda Amaze VX i-DTEC  2014         450000
# 5                             Maruti Alto LX BSIII  2007         140000
# 6                        Hyundai Xcent 1.2 Kappa S  2016         550000
# 7                         Tata Indigo Grand Petrol  2014         240000
# 8                         Hyundai Creta 1.6 VTVT S  2015         850000
# 9                         Maruti Celerio Green VXI  2017         365000
# 10                         Chevrolet Sail 1.2 Base  2015         260000
# 11                        Tata Indigo Grand Petrol  2014         250000
# ...

# %%
df.tail()
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
df.tail(10)
# Out:
#                                               name  year  selling_price  \
# 4330                Tata Indica Vista Aqua 1.4 TDI  2010         150000
# 4331          Ford EcoSport 1.5 TDCi Titanium BSIV  2015         530000
# 4332                  Mahindra Scorpio S2 7 Seater  2015         750000
# 4333                               Maruti Ritz VDi  2012         225000
# 4334  Toyota Innova 2.5 VX (Diesel) 8 Seater BS IV  2012         600000
# 4335           Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999
# 4336                    Hyundai i20 Magna 1.4 CRDi  2014         409999
# 4337                           Maruti 800 AC BSIII  2009         110000
# 4338              Hyundai Creta 1.6 CRDi SX Option  2016         865000
# 4339                              Renault KWID RXT  2016         225000
#
#       km_driven    fuel seller_type transmission         owner
# 4330     130000  Diesel  Individual       Manual  Second Owner
# ...

# %%
# sample

# %%
df.sample()
# Out:
#                  name  year  selling_price  km_driven    fuel seller_type  \
# 1782  Tata Indica DLE  2006          45000     120000  Diesel  Individual
#
#      transmission         owner
# 1782       Manual  Second Owner

# %%
df.sample()
# Out:
#                       name  year  selling_price  km_driven    fuel  \
# 1870  Maruti Swift 1.2 DLX  2015         220000      40000  Petrol
#
#      seller_type transmission        owner
# 1870  Individual       Manual  First Owner

# %%
df.sample()
# Out:
#                  name  year  selling_price  km_driven    fuel seller_type  \
# 2464  Maruti Ritz VDi  2011         260000      52895  Diesel      Dealer
#
#      transmission        owner
# 2464       Manual  First Owner

# %%
df.sample()
# Out:
#                    name  year  selling_price  km_driven    fuel seller_type  \
# 294  Maruti Wagon R VXI  2014         315000      41000  Petrol      Dealer
#
#     transmission        owner
# 294       Manual  First Owner

# %%
df.sample()
# Out:
#                                   name  year  selling_price  km_driven  \
# 4139  Maruti S-Cross Alpha DDiS 200 SH  2018         950000      30000
#
#         fuel seller_type transmission        owner
# 4139  Diesel  Individual       Manual  First Owner

# %%
df.sample(2)
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 4152  Hyundai Accent Executive CNG  2010         140000     110000     CNG
# 2141          Maruti Swift 1.2 DLX  2015         217000      45000  Petrol
#
#      seller_type transmission        owner
# 4152  Individual       Manual  First Owner
# 2141  Individual       Manual  First Owner

# %%
df.sample(5)
# Out:
#                                    name  year  selling_price  km_driven  \
# 4286             Fiat Punto 1.3 Emotion  2010         130000     210000
# 1704              Maruti Swift VXI BSIV  2016         500000      60000
# 2315  Skoda Octavia Elegance 2.0 TDI AT  2014        1200000     135000
# 4182                     Maruti Alto LX  2011         135000      50000
# 1758                    Hyundai EON Era  2014         290000      12000
#
#         fuel seller_type transmission         owner
# 4286  Diesel  Individual       Manual  Second Owner
# 1704  Petrol  Individual       Manual   First Owner
# 2315  Diesel  Individual    Automatic   Third Owner
# 4182  Petrol  Individual       Manual   First Owner
# 1758  Petrol      Dealer       Manual   First Owner

# %%
#describe
#information

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4340 non-null   object
#  1   year           4340 non-null   int64
#  2   selling_price  4340 non-null   int64
#  3   km_driven      4340 non-null   int64
#  4   fuel           4340 non-null   object
#  5   seller_type    4340 non-null   object
#  6   transmission   4340 non-null   object
#  7   owner          4340 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 271.4+ KB

# %%
# checking null value in the data
# isnull
# notnull

# %%
df.isnull()
# Out:
#        name   year  selling_price  km_driven   fuel  seller_type  \
# 0     False  False          False      False  False        False
# 1     False  False          False      False  False        False
# 2     False  False          False      False  False        False
# 3     False  False          False      False  False        False
# 4     False  False          False      False  False        False
# ...     ...    ...            ...        ...    ...          ...
# 4335  False  False          False      False  False        False
# 4336  False  False          False      False  False        False
# 4337  False  False          False      False  False        False
# 4338  False  False          False      False  False        False
# 4339  False  False          False      False  False        False
#
#       transmission  owner
# 0            False  False
# 1            False  False
# 2            False  False
# 3            False  False
# 4            False  False
# ...

# %%
df.notnull()
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0     True  True           True       True  True         True          True
# 1     True  True           True       True  True         True          True
# 2     True  True           True       True  True         True          True
# 3     True  True           True       True  True         True          True
# 4     True  True           True       True  True         True          True
# ...    ...   ...            ...        ...   ...          ...           ...
# 4335  True  True           True       True  True         True          True
# 4336  True  True           True       True  True         True          True
# 4337  True  True           True       True  True         True          True
# 4338  True  True           True       True  True         True          True
# 4339  True  True           True       True  True         True          True
#
#       owner
# 0      True
# 1      True
# 2      True
# ...

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# name             4340
# year             4340
# selling_price    4340
# km_driven        4340
# fuel             4340
# seller_type      4340
# transmission     4340
# owner            4340
# dtype: int64

# %%
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__deprecated_num_index_names',
#  '__dir__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
# ...
